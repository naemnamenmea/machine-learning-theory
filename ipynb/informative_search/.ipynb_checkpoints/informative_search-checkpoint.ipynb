# %% [markdown]
# # Developing a fast Indexing and Full text Search Engine with Whoosh: A Pure-Python Library
#
# <u>Problem Statement</u>: To simply put, You have 1 million text files in a directory and your application must cater text query search on all files within few seconds (say ~1-2 seconds). How will you develop such system !!.
#
# <u>Motivation</u>: The idea came from my previous post “Performing OCR by running parallel instances of Tesseract 4.0 : Python“. Saying that following could be some use cases where you may have to build such search engine on top of other applications. e.g.
#
# * You have built an OCR app and converted millions of images into text files. You may want to build a search engine over converted text files to search contents of images.
# * You have built a speech to text system where you are converting thousands of recorded audios into text data. You may like to search contents of audio in real time.
#
# ## Introduction: Whoosh
#
# Whoosh is a fast, featureful full-text indexing and searching library implemented in pure Python. Programmers can use it to easily add search functionality to their applications and websites.
#
# Whoosh pypi package can simply be installed with pip:
#
# ```
# pip install Whoosh
# ```
#
# For the example demonstrated in this blog-post, You can download  a data-set of 70,000 text files which were taken from simple wiki articles from [here](https://drive.google.com/file/d/1iKqQqrasxqDfTYwPyRjddxoUlPW602jv/view).
#
# ## 1. Creating Indexed Data: Whoosh
#
# It is easy to index all your text files with Whoosh. Initially, the schema of the index has to be defined. Schema defines list of fields to be indexed or stored for each text file. It’s similar to how we define it for database. A field is a piece of information for each document in the index, such as its title or text content. Indexing of a field means it can be searched and it is also returned with results if defined as argument (stored=True) in schema. You only need to create the schema once while creating the index.
#
# Finally, all the text documents are added to index writer in loop. Documents are indexed as per schema and has to be added as per schema design. Below is the python implementation for indexing  all the text documents of a directory.

# %%
import os
from whoosh.index import create_in
from whoosh.fields import Schema, TEXT, ID
import sys
 
def createSearchableData(root):   
 
    '''
    Schema definition: title(name of file), path(as ID), content(indexed
    but not stored),textdata (stored text content)
    '''
    schema = Schema(title=TEXT(stored=True),path=ID(stored=True),\
              content=TEXT,textdata=TEXT(stored=True))
    if not os.path.exists("indexdir"):
        os.mkdir("indexdir")
 
    # Creating a index writer to add document as per schema
    ix = create_in("indexdir",schema)
    writer = ix.writer()
 
    filepaths = [os.path.join(root,i) for i in os.listdir(root)]
    for path in filepaths:
        fp = open(path,'r')
        print(path)
        text = fp.read()
        writer.add_document(title=path.split("\\")[1], path=path,\
          content=text,textdata=text)
        fp.close()
    writer.commit()
 
root = "corpus"
createSearchableData(root)
# Out:
# corpus\0.txt
# corpus\1.txt
# corpus\10.txt
# corpus\100.txt
# corpus\1000.txt
# corpus\10000.txt
# corpus\10001.txt
# corpus\10002.txt
# corpus\10003.txt
# corpus\10004.txt
# corpus\10005.txt
# corpus\10006.txt
# corpus\10007.txt
# corpus\10008.txt
# corpus\10009.txt
# corpus\1001.txt
# corpus\10010.txt
# corpus\10011.txt
# corpus\10012.txt
# corpus\10013.txt
# corpus\10014.txt
# corpus\10015.txt
# corpus\10016.txt
# corpus\10017.txt
# corpus\10018.txt
# corpus\10019.txt
# corpus\1002.txt
# corpus\10020.txt
# corpus\10021.txt
# corpus\10022.txt
# corpus\10023.txt
# corpus\10024.txt
# corpus\10025.txt
# corpus\10026.txt
# corpus\10027.txt
# corpus\10028.txt
# corpus\10029.txt
# corpus\1003.txt
# corpus\10030.txt
# corpus\10031.txt
# corpus\10032.txt
# corpus\10033.txt
# corpus\10034.txt
# corpus\10035.txt
# corpus\10036.txt
# corpus\10037.txt
# corpus\10038.txt
# corpus\10039.txt
# corpus\1004.txt
# corpus\10040.txt
# corpus\10041.txt
# corpus\10042.txt
# corpus\10043.txt
# corpus\10044.txt
# corpus\10045.txt
# corpus\10046.txt
# corpus\10047.txt
# corpus\10048.txt
# corpus\10049.txt
# corpus\1005.txt
# corpus\10050.txt
# corpus\10051.txt
# corpus\10052.txt
# corpus\10053.txt
# corpus\10054.txt
# corpus\10055.txt
# corpus\10056.txt
# corpus\10057.txt
# corpus\10058.txt
# corpus\10059.txt
# corpus\1006.txt
# corpus\10060.txt
# corpus\10061.txt
# corpus\10062.txt
# corpus\10063.txt
# corpus\10064.txt
# corpus\10065.txt
# corpus\10066.txt
# corpus\10067.txt
# corpus\10068.txt
# corpus\10069.txt
# corpus\1007.txt
# corpus\10070.txt
# corpus\10071.txt
# corpus\10072.txt
# corpus\10073.txt
# corpus\10074.txt
# corpus\10075.txt
# corpus\10076.txt
# corpus\10077.txt
# corpus\10078.txt
# corpus\10079.txt
# corpus\1008.txt
# corpus\10080.txt
# corpus\10081.txt
# corpus\10082.txt
# corpus\10083.txt
# corpus\10084.txt
# corpus\10085.txt
# corpus\10086.txt
# corpus\10087.txt
# corpus\10088.txt
# corpus\10089.txt
# corpus\1009.txt
# corpus\10090.txt
# corpus\10091.txt
# corpus\10092.txt
# corpus\10093.txt
# corpus\10094.txt
# corpus\10095.txt
# corpus\10096.txt
# corpus\10097.txt
# corpus\10098.txt
# corpus\10099.txt
# corpus\101.txt
# corpus\1010.txt
# corpus\10100.txt
# corpus\10101.txt
# corpus\10102.txt
# corpus\10103.txt
# corpus\10104.txt
# corpus\10105.txt
# corpus\10106.txt
# corpus\10107.txt
# corpus\10108.txt
# corpus\10109.txt
# corpus\1011.txt
# corpus\10110.txt
# corpus\10111.txt
# corpus\10112.txt
# corpus\10113.txt
# corpus\10114.txt
# corpus\10115.txt
# corpus\10116.txt
# corpus\10117.txt
# corpus\10118.txt
# corpus\10119.txt
# corpus\1012.txt
# corpus\10120.txt
# corpus\10121.txt
# corpus\10122.txt
# corpus\10123.txt
# corpus\10124.txt
# corpus\10125.txt
# corpus\10126.txt
# corpus\10127.txt
# corpus\10128.txt
# corpus\10129.txt
# corpus\1013.txt
# corpus\10130.txt
# corpus\10131.txt
# corpus\10132.txt
# corpus\10133.txt
# corpus\10134.txt
# corpus\10135.txt
# corpus\10136.txt
# corpus\10137.txt
# corpus\10138.txt
# corpus\10139.txt
# corpus\1014.txt
# corpus\10140.txt
# corpus\10141.txt
# corpus\10142.txt
# corpus\10143.txt
# corpus\10144.txt
# corpus\10145.txt
# corpus\10146.txt
# corpus\10147.txt
# corpus\10148.txt
# corpus\10149.txt
# corpus\1015.txt
# corpus\10150.txt
# corpus\10151.txt
# corpus\10152.txt
# corpus\10153.txt
# corpus\10154.txt
# corpus\10155.txt
# corpus\10156.txt
# corpus\10157.txt
# corpus\10158.txt
# corpus\10159.txt
# corpus\1016.txt
# corpus\10160.txt
# corpus\10161.txt
# corpus\10162.txt
# corpus\10163.txt
# corpus\10164.txt
# corpus\10165.txt
# corpus\10166.txt
# corpus\10167.txt
# corpus\10168.txt
# corpus\10169.txt
# corpus\1017.txt
# corpus\10170.txt
# corpus\10171.txt
# corpus\10172.txt
# corpus\10173.txt
# corpus\10174.txt
# corpus\10175.txt
# corpus\10176.txt
# corpus\10177.txt
# corpus\10178.txt
# corpus\10179.txt
# corpus\1018.txt
# corpus\10180.txt
# corpus\10181.txt
# corpus\10182.txt
# corpus\10183.txt
# corpus\10184.txt
# corpus\10185.txt
# corpus\10186.txt
# corpus\10187.txt
# corpus\10188.txt
# corpus\10189.txt
# corpus\1019.txt
# corpus\10190.txt
# corpus\10191.txt
# corpus\10192.txt
# corpus\10193.txt
# corpus\10194.txt
# corpus\10195.txt
# corpus\10196.txt
# corpus\10197.txt
# corpus\10198.txt
# corpus\10199.txt
# corpus\102.txt
# corpus\1020.txt
# corpus\10200.txt
# corpus\10201.txt
# corpus\10202.txt
# corpus\10203.txt
# corpus\10204.txt
# corpus\10205.txt
# corpus\10206.txt
# corpus\10207.txt
# corpus\10208.txt
# corpus\10209.txt
# corpus\1021.txt
# corpus\10210.txt
# corpus\10211.txt
# corpus\10212.txt
# corpus\10213.txt
# corpus\10214.txt
# corpus\10215.txt
# corpus\10216.txt
# corpus\10217.txt
# corpus\10218.txt
# corpus\10219.txt
# corpus\1022.txt
# corpus\10220.txt
# corpus\10221.txt
# corpus\10222.txt
# corpus\10223.txt
# corpus\10224.txt
# corpus\10225.txt
# corpus\10226.txt
# corpus\10227.txt
# corpus\10228.txt
# corpus\10229.txt
# corpus\1023.txt
# corpus\10230.txt
# corpus\10231.txt
# corpus\10232.txt
# corpus\10233.txt
# corpus\10234.txt
# corpus\10235.txt
# corpus\10236.txt
# corpus\10237.txt
# corpus\10238.txt
# corpus\10239.txt
# corpus\1024.txt
# corpus\10240.txt
# corpus\10241.txt
# corpus\10242.txt
# corpus\10243.txt
# corpus\10244.txt
# corpus\10245.txt
# corpus\10246.txt
# corpus\10247.txt
# corpus\10248.txt
# corpus\10249.txt
# corpus\1025.txt
# corpus\10250.txt
# corpus\10251.txt
# corpus\10252.txt
# corpus\10253.txt
# corpus\10254.txt
# corpus\10255.txt
# corpus\10256.txt
# corpus\10257.txt
# corpus\10258.txt
# corpus\10259.txt
# corpus\1026.txt
# corpus\10260.txt
# corpus\10261.txt
# corpus\10262.txt
# corpus\10263.txt
# corpus\10264.txt
# corpus\10265.txt
# corpus\10266.txt
# corpus\10267.txt
# corpus\10268.txt
# corpus\10269.txt
# corpus\1027.txt
# corpus\10270.txt
# corpus\10271.txt
# corpus\10272.txt
# corpus\10273.txt
# corpus\10274.txt
# corpus\10275.txt
# corpus\10276.txt
# corpus\10277.txt
# corpus\10278.txt
# corpus\10279.txt
# corpus\1028.txt
# corpus\10280.txt
# corpus\10281.txt
# corpus\10282.txt
# corpus\10283.txt
# corpus\10284.txt
# corpus\10285.txt
# corpus\10286.txt
# corpus\10287.txt
# corpus\10288.txt
# corpus\10289.txt
# corpus\1029.txt
# corpus\10290.txt
# corpus\10291.txt
# corpus\10292.txt
# corpus\10293.txt
# corpus\10294.txt
# corpus\10295.txt
# corpus\10296.txt
# corpus\10297.txt
# corpus\10298.txt
# corpus\10299.txt
# corpus\103.txt
# corpus\1030.txt
# corpus\10300.txt
# corpus\10301.txt
# corpus\10302.txt
# corpus\10303.txt
# corpus\10304.txt
# corpus\10305.txt
# corpus\10306.txt
# corpus\10307.txt
# corpus\10308.txt
# corpus\10309.txt
# corpus\1031.txt
# corpus\10310.txt
# corpus\10311.txt
# corpus\10312.txt
# corpus\10313.txt
# corpus\10314.txt
# corpus\10315.txt
# corpus\10316.txt
# corpus\10317.txt
# corpus\10318.txt
# corpus\10319.txt
# corpus\1032.txt
# corpus\10320.txt
# corpus\10321.txt
# corpus\10322.txt
# corpus\10323.txt
# corpus\10324.txt
# corpus\10325.txt
# corpus\10326.txt
# corpus\10327.txt
# corpus\10328.txt
# corpus\10329.txt
# corpus\1033.txt
# corpus\10330.txt
# corpus\10331.txt
# corpus\10332.txt
# corpus\10333.txt
# corpus\10334.txt
# corpus\10335.txt
# corpus\10336.txt
# corpus\10337.txt
# corpus\10338.txt
# corpus\10339.txt
# corpus\1034.txt
# corpus\10340.txt
# corpus\10341.txt
# corpus\10342.txt
# corpus\10343.txt
# corpus\10344.txt
# corpus\10345.txt
# corpus\10346.txt
# corpus\10347.txt
# corpus\10348.txt
# corpus\10349.txt
# corpus\1035.txt
# corpus\10350.txt
# corpus\10351.txt
# corpus\10352.txt
# corpus\10353.txt
# corpus\10354.txt
# corpus\10355.txt
# corpus\10356.txt
# corpus\10357.txt
# corpus\10358.txt
# corpus\10359.txt
# corpus\1036.txt
# corpus\10360.txt
# corpus\10361.txt
# corpus\10362.txt
# corpus\10363.txt
# corpus\10364.txt
# corpus\10365.txt
# corpus\10366.txt
# corpus\10367.txt
# corpus\10368.txt
# corpus\10369.txt
# corpus\1037.txt
# corpus\10370.txt
# corpus\10371.txt
# corpus\10372.txt
# corpus\10373.txt
# corpus\10374.txt
# corpus\10375.txt
# corpus\10376.txt
# corpus\10377.txt
# corpus\10378.txt
# corpus\10379.txt
# corpus\1038.txt
# corpus\10380.txt
# corpus\10381.txt
# corpus\10382.txt
# corpus\10383.txt
# corpus\10384.txt
# corpus\10385.txt
# corpus\10386.txt
# corpus\10387.txt
# corpus\10388.txt
# corpus\10389.txt
# corpus\1039.txt
# corpus\10390.txt
# corpus\10391.txt
# corpus\10392.txt
# corpus\10393.txt
# corpus\10394.txt
# corpus\10395.txt
# corpus\10396.txt
# corpus\10397.txt
# corpus\10398.txt
# corpus\10399.txt
# corpus\104.txt
# corpus\1040.txt
# corpus\10400.txt
# corpus\10401.txt
# corpus\10402.txt
# corpus\10403.txt
# corpus\10404.txt
# corpus\10405.txt
# corpus\10406.txt
# corpus\10407.txt
# corpus\10408.txt
# corpus\10409.txt
# corpus\1041.txt
# corpus\10410.txt
# corpus\10411.txt
# corpus\10412.txt
# corpus\10413.txt
# corpus\10414.txt
# corpus\10415.txt
# corpus\10416.txt
# corpus\10417.txt
# corpus\10418.txt
# corpus\10419.txt
# corpus\1042.txt
# corpus\10420.txt
# corpus\10421.txt
# corpus\10422.txt
# corpus\10423.txt
# corpus\10424.txt
# corpus\10425.txt
# corpus\10426.txt
# corpus\10427.txt
# corpus\10428.txt
# corpus\10429.txt
# corpus\1043.txt
# corpus\10430.txt
# corpus\10431.txt
# corpus\10432.txt
# corpus\10433.txt
# corpus\10434.txt
# corpus\10435.txt
# corpus\10436.txt
# corpus\10437.txt
# corpus\10438.txt
# corpus\10439.txt
# corpus\1044.txt
# corpus\10440.txt
# corpus\10441.txt
# corpus\10442.txt
# corpus\10443.txt
# corpus\10444.txt
# corpus\10445.txt
# corpus\10446.txt
# corpus\10447.txt
# corpus\10448.txt
# corpus\10449.txt
# corpus\1045.txt
# corpus\10450.txt
# corpus\10451.txt
# corpus\10452.txt
# corpus\10453.txt
# corpus\10454.txt
# corpus\10455.txt
# corpus\10456.txt
# corpus\10457.txt
# corpus\10458.txt
# corpus\10459.txt
# corpus\1046.txt
# corpus\10460.txt
# corpus\10461.txt
# corpus\10462.txt
# corpus\10463.txt
# corpus\10464.txt
# corpus\10465.txt
# corpus\10466.txt
# corpus\10467.txt
# corpus\10468.txt
# corpus\10469.txt
# corpus\1047.txt
# corpus\10470.txt
# corpus\10471.txt
# corpus\10472.txt
# corpus\10473.txt
# corpus\10474.txt
# corpus\10475.txt
# corpus\10476.txt
# corpus\10477.txt
# corpus\10478.txt
# corpus\10479.txt
# corpus\1048.txt
# corpus\10480.txt
# corpus\10481.txt
# corpus\10482.txt
# corpus\10483.txt
# corpus\10484.txt
# corpus\10485.txt
# corpus\10486.txt
# corpus\10487.txt
# corpus\10488.txt
# corpus\10489.txt
# corpus\1049.txt
# corpus\10490.txt
# corpus\10491.txt
# corpus\10492.txt
# corpus\10493.txt
# corpus\10494.txt
# corpus\10495.txt
# corpus\10496.txt
# corpus\10497.txt
# corpus\10498.txt
# corpus\10499.txt
# corpus\105.txt
# corpus\1050.txt
# corpus\10500.txt
# corpus\10501.txt
# corpus\10502.txt
# corpus\10503.txt
# corpus\10504.txt
# corpus\10505.txt
# corpus\10506.txt
# corpus\10507.txt
# corpus\10508.txt
# corpus\10509.txt
# corpus\1051.txt
# corpus\10510.txt
# corpus\10511.txt
# corpus\10512.txt
# corpus\10513.txt
# corpus\10514.txt
# corpus\10515.txt
# corpus\10516.txt
# corpus\10517.txt
# corpus\10518.txt
# corpus\10519.txt
# corpus\1052.txt
# corpus\10520.txt
# corpus\10521.txt
# corpus\10522.txt
# corpus\10523.txt
# corpus\10524.txt
# corpus\10525.txt
# corpus\10526.txt
# corpus\10527.txt
# corpus\10528.txt
# corpus\10529.txt
# corpus\1053.txt
# corpus\10530.txt
# corpus\10531.txt
# corpus\10532.txt
# corpus\10533.txt
# corpus\10534.txt
# corpus\10535.txt
# corpus\10536.txt
# corpus\10537.txt
# corpus\10538.txt
# corpus\10539.txt
# corpus\1054.txt
# corpus\10540.txt
# corpus\10541.txt
# corpus\10542.txt
# corpus\10543.txt
# corpus\10544.txt
# corpus\10545.txt
# corpus\10546.txt
# corpus\10547.txt
# corpus\10548.txt
# corpus\10549.txt
# corpus\1055.txt
# corpus\10550.txt
# corpus\10551.txt
# corpus\10552.txt
# corpus\10553.txt
# corpus\10554.txt
# corpus\10555.txt
# corpus\10556.txt
# corpus\10557.txt
# corpus\10558.txt
# corpus\10559.txt
# corpus\1056.txt
# corpus\10560.txt
# corpus\10561.txt
# corpus\10562.txt
# corpus\10563.txt
# corpus\10564.txt
# corpus\10565.txt
# corpus\10566.txt
# corpus\10567.txt
# corpus\10568.txt
# corpus\10569.txt
# corpus\1057.txt
# corpus\10570.txt
# corpus\10571.txt
# corpus\10572.txt
# corpus\10573.txt
# corpus\10574.txt
# corpus\10575.txt
# corpus\10576.txt
# corpus\10577.txt
# corpus\10578.txt
# corpus\10579.txt
# corpus\1058.txt
# corpus\10580.txt
# corpus\10581.txt
# corpus\10582.txt
# corpus\10583.txt
# corpus\10584.txt
# corpus\10585.txt
# corpus\10586.txt
# corpus\10587.txt
# corpus\10588.txt
# corpus\10589.txt
# corpus\1059.txt
# corpus\10590.txt
# corpus\10591.txt
# corpus\10592.txt
# corpus\10593.txt
# corpus\10594.txt
# corpus\10595.txt
# corpus\10596.txt
# corpus\10597.txt
# corpus\10598.txt
# corpus\10599.txt
# corpus\106.txt
# corpus\1060.txt
# corpus\10600.txt
# corpus\10601.txt
# corpus\10602.txt
# corpus\10603.txt
# corpus\10604.txt
# corpus\10605.txt
# corpus\10606.txt
# corpus\10607.txt
# corpus\10608.txt
# corpus\10609.txt
# corpus\1061.txt
# corpus\10610.txt
# corpus\10611.txt
# corpus\10612.txt
# corpus\10613.txt
# corpus\10614.txt
# corpus\10615.txt
# corpus\10616.txt
# corpus\10617.txt
# corpus\10618.txt
# corpus\10619.txt
# corpus\1062.txt
# corpus\10620.txt
# corpus\10621.txt
# corpus\10622.txt
# corpus\10623.txt
# corpus\10624.txt
# corpus\10625.txt
# corpus\10626.txt
# corpus\10627.txt
# corpus\10628.txt
# corpus\10629.txt
# corpus\1063.txt
# corpus\10630.txt
# corpus\10631.txt
# corpus\10632.txt
# corpus\10633.txt
# corpus\10634.txt
# corpus\10635.txt
# corpus\10636.txt
# corpus\10637.txt
# corpus\10638.txt
# corpus\10639.txt
# corpus\1064.txt
# corpus\10640.txt
# corpus\10641.txt
# corpus\10642.txt
# corpus\10643.txt
# corpus\10644.txt
# corpus\10645.txt
# corpus\10646.txt
# corpus\10647.txt
# corpus\10648.txt
# corpus\10649.txt
# corpus\1065.txt
# corpus\10650.txt
# corpus\10651.txt
# corpus\10652.txt
# corpus\10653.txt
# corpus\10654.txt
# corpus\10655.txt
# corpus\10656.txt
# corpus\10657.txt
# corpus\10658.txt
# corpus\10659.txt
# corpus\1066.txt
# corpus\10660.txt
# corpus\10661.txt
# corpus\10662.txt
# corpus\10663.txt
# corpus\10664.txt
# corpus\10665.txt
# corpus\10666.txt
# corpus\10667.txt
# corpus\10668.txt
# corpus\10669.txt
# corpus\1067.txt
# corpus\10670.txt
# corpus\10671.txt
# corpus\10672.txt
# corpus\10673.txt
# corpus\10674.txt
# corpus\10675.txt
# corpus\10676.txt
# corpus\10677.txt
# corpus\10678.txt
# corpus\10679.txt
# corpus\1068.txt
# corpus\10680.txt
# corpus\10681.txt
# corpus\10682.txt
# corpus\10683.txt
# corpus\10684.txt
# corpus\10685.txt
# corpus\10686.txt
# corpus\10687.txt
# corpus\10688.txt
# corpus\10689.txt
# corpus\1069.txt
# corpus\10690.txt
# corpus\10691.txt
# corpus\10692.txt
# corpus\10693.txt
# corpus\10694.txt
# corpus\10695.txt
# corpus\10696.txt
# corpus\10697.txt
# corpus\10698.txt
# corpus\10699.txt
# corpus\107.txt
# corpus\1070.txt
# corpus\10700.txt
# corpus\10701.txt
# corpus\10702.txt
# corpus\10703.txt
# corpus\10704.txt
# corpus\10705.txt
# corpus\10706.txt
# corpus\10707.txt
# corpus\10708.txt
# corpus\10709.txt
# corpus\1071.txt
# corpus\10710.txt
# corpus\10711.txt
# corpus\10712.txt
# corpus\10713.txt
# corpus\10714.txt
# corpus\10715.txt
# corpus\10716.txt
# corpus\10717.txt
# corpus\10718.txt
# corpus\10719.txt
# corpus\1072.txt
# corpus\10720.txt
# corpus\10721.txt
# corpus\10722.txt
# corpus\10723.txt
# corpus\10724.txt
# corpus\10725.txt
# corpus\10726.txt
# corpus\10727.txt
# corpus\10728.txt
# corpus\10729.txt
# corpus\1073.txt
# corpus\10730.txt
# corpus\10731.txt
# corpus\10732.txt
# corpus\10733.txt
# corpus\10734.txt
# corpus\10735.txt
# corpus\10736.txt
# corpus\10737.txt
# corpus\10738.txt
# corpus\10739.txt
# corpus\1074.txt
# corpus\10740.txt
# corpus\10741.txt
# corpus\10742.txt
# corpus\10743.txt
# corpus\10744.txt
# corpus\10745.txt
# corpus\10746.txt
# corpus\10747.txt
# corpus\10748.txt
# corpus\10749.txt
# corpus\1075.txt
# corpus\10750.txt
# corpus\10751.txt
# corpus\10752.txt
# corpus\10753.txt
# corpus\10754.txt
# corpus\10755.txt
# corpus\10756.txt
# corpus\10757.txt
# corpus\10758.txt
# corpus\10759.txt
# corpus\1076.txt
# corpus\10760.txt
# corpus\10761.txt
# corpus\10762.txt
# corpus\10763.txt
# corpus\10764.txt
# corpus\10765.txt
# corpus\10766.txt
# corpus\10767.txt
# corpus\10768.txt
# corpus\10769.txt
# corpus\1077.txt
# corpus\10770.txt
# corpus\10771.txt
# corpus\10772.txt
# corpus\10773.txt
# corpus\10774.txt
# corpus\10775.txt
# corpus\10776.txt
# corpus\10777.txt
# corpus\10778.txt
# corpus\10779.txt
# corpus\1078.txt
# corpus\10780.txt
# corpus\10781.txt
# corpus\10782.txt
# corpus\10783.txt
# corpus\10784.txt
# corpus\10785.txt
# corpus\10786.txt
# corpus\10787.txt
# corpus\10788.txt
# corpus\10789.txt
# corpus\1079.txt
# corpus\10790.txt
# corpus\10791.txt
# corpus\10792.txt
# corpus\10793.txt
# corpus\10794.txt
# corpus\10795.txt
# corpus\10796.txt
# corpus\10797.txt
# corpus\10798.txt
# corpus\10799.txt
# corpus\108.txt
# corpus\1080.txt
# corpus\10800.txt
# corpus\10801.txt
# corpus\10802.txt
# corpus\10803.txt
# corpus\10804.txt
# corpus\10805.txt
# corpus\10806.txt
# corpus\10807.txt
# corpus\10808.txt
# corpus\10809.txt
# corpus\1081.txt
# corpus\10810.txt
# corpus\10811.txt
# corpus\10812.txt
# corpus\10813.txt
# corpus\10814.txt
# corpus\10815.txt
# corpus\10816.txt
# corpus\10817.txt
# corpus\10818.txt
# corpus\10819.txt
# corpus\1082.txt
# corpus\10820.txt
# corpus\10821.txt
# corpus\10822.txt
# corpus\10823.txt
# corpus\10824.txt
# corpus\10825.txt
# corpus\10826.txt
# corpus\10827.txt
# corpus\10828.txt
# corpus\10829.txt
# corpus\1083.txt
# corpus\10830.txt
# corpus\10831.txt
# corpus\10832.txt
# corpus\10833.txt
# corpus\10834.txt
# corpus\10835.txt
# corpus\10836.txt
# corpus\10837.txt
# corpus\10838.txt
# corpus\10839.txt
# corpus\1084.txt
# corpus\10840.txt
# corpus\10841.txt
# corpus\10842.txt
# corpus\10843.txt
# corpus\10844.txt
# corpus\10845.txt
# corpus\10846.txt
# corpus\10847.txt
# corpus\10848.txt
# corpus\10849.txt
# corpus\1085.txt
# corpus\10850.txt
# corpus\10851.txt
# corpus\10852.txt
# corpus\10853.txt
# corpus\10854.txt
# corpus\10855.txt
# corpus\10856.txt
# corpus\10857.txt
# corpus\10858.txt
# corpus\10859.txt
# corpus\1086.txt
# corpus\10860.txt
# corpus\10861.txt
# corpus\10862.txt
# corpus\10863.txt
# corpus\10864.txt
# corpus\10865.txt
# corpus\10866.txt
# corpus\10867.txt
# corpus\10868.txt
# corpus\10869.txt
# corpus\1087.txt
# corpus\10870.txt
# corpus\10871.txt
# corpus\10872.txt
# corpus\10873.txt
# corpus\10874.txt
# corpus\10875.txt
# corpus\10876.txt
# corpus\10877.txt
# corpus\10878.txt
# corpus\10879.txt
# corpus\1088.txt
# corpus\10880.txt
# corpus\10881.txt
# corpus\10882.txt
# corpus\10883.txt
# corpus\10884.txt
# corpus\10885.txt
# corpus\10886.txt
# corpus\10887.txt
# corpus\10888.txt
# corpus\10889.txt
# corpus\1089.txt
# corpus\10890.txt
# corpus\10891.txt
# corpus\10892.txt
# corpus\10893.txt
# corpus\10894.txt
# corpus\10895.txt
# corpus\10896.txt
# corpus\10897.txt
# corpus\10898.txt
# corpus\10899.txt
# corpus\109.txt
# corpus\1090.txt
# corpus\10900.txt
# corpus\10901.txt
# corpus\10902.txt
# corpus\10903.txt
# corpus\10904.txt
# corpus\10905.txt
# corpus\10906.txt
# corpus\10907.txt
# corpus\10908.txt
# corpus\10909.txt
# corpus\1091.txt
# corpus\10910.txt
# corpus\10911.txt
# corpus\10912.txt
# corpus\10913.txt
# corpus\10914.txt
# corpus\10915.txt
# corpus\10916.txt
# corpus\10917.txt
# corpus\10918.txt
# corpus\10919.txt
# corpus\1092.txt
# corpus\10920.txt
# corpus\10921.txt
# corpus\10922.txt
# corpus\10923.txt
# corpus\10924.txt
# corpus\10925.txt
# corpus\10926.txt
# corpus\10927.txt
# corpus\10928.txt
# corpus\10929.txt
# corpus\1093.txt
# corpus\10930.txt
# corpus\10931.txt
# corpus\10932.txt
# corpus\10933.txt
# corpus\10934.txt
# corpus\10935.txt
# corpus\10936.txt
# corpus\10937.txt
# corpus\10938.txt
# corpus\10939.txt
# corpus\1094.txt
# corpus\10940.txt
# corpus\10941.txt
# corpus\10942.txt
# corpus\10943.txt
# corpus\10944.txt
# corpus\10945.txt
# corpus\10946.txt
# corpus\10947.txt
# corpus\10948.txt
# corpus\10949.txt
# corpus\1095.txt
# corpus\10950.txt
# corpus\10951.txt
# corpus\10952.txt
# corpus\10953.txt
# corpus\10954.txt
# corpus\10955.txt
# corpus\10956.txt
# corpus\10957.txt
# corpus\10958.txt
# corpus\10959.txt
# corpus\1096.txt
# corpus\10960.txt
# corpus\10961.txt
# corpus\10962.txt
# corpus\10963.txt
# corpus\10964.txt
# corpus\10965.txt
# corpus\10966.txt
# corpus\10967.txt
# corpus\10968.txt
# corpus\10969.txt
# corpus\1097.txt
# corpus\10970.txt
# corpus\10971.txt
# corpus\10972.txt
# corpus\10973.txt
# corpus\10974.txt
# corpus\10975.txt
# corpus\10976.txt
# corpus\10977.txt
# corpus\10978.txt
# corpus\10979.txt
# corpus\1098.txt
# corpus\10980.txt
# corpus\10981.txt
# corpus\10982.txt
# corpus\10983.txt
# corpus\10984.txt
# corpus\10985.txt
# corpus\10986.txt
# corpus\10987.txt
# corpus\10988.txt
# corpus\10989.txt
# corpus\1099.txt
# corpus\10990.txt
# corpus\10991.txt
# corpus\10992.txt
# corpus\10993.txt
# corpus\10994.txt
# corpus\10995.txt
# corpus\10996.txt
# corpus\10997.txt
# corpus\10998.txt
# corpus\10999.txt
# corpus\11.txt
# corpus\110.txt
# corpus\1100.txt
# corpus\11000.txt
# corpus\11001.txt
# corpus\11002.txt
# corpus\11003.txt
# corpus\11004.txt
# corpus\11005.txt
# corpus\11006.txt
# corpus\11007.txt
# corpus\11008.txt
# corpus\11009.txt
# corpus\1101.txt
# corpus\11010.txt
# corpus\11011.txt
# corpus\11012.txt
# corpus\11013.txt
# corpus\11014.txt
# corpus\11015.txt
# corpus\11016.txt
# corpus\11017.txt
# corpus\11018.txt
# corpus\11019.txt
# corpus\1102.txt
# corpus\11020.txt
# corpus\11021.txt
# corpus\11022.txt
# corpus\11023.txt
# corpus\11024.txt
# corpus\11025.txt
# corpus\11026.txt
# corpus\11027.txt
# corpus\11028.txt
# corpus\11029.txt
# corpus\1103.txt
# corpus\11030.txt
# corpus\11031.txt
# corpus\11032.txt
# corpus\11033.txt
# corpus\11034.txt
# corpus\11035.txt
# corpus\11036.txt
# corpus\11037.txt
# corpus\11038.txt
# corpus\11039.txt
# corpus\1104.txt
# corpus\11040.txt
# corpus\11041.txt
# corpus\11042.txt
# corpus\11043.txt
# corpus\11044.txt
# corpus\11045.txt
# corpus\11046.txt
# corpus\11047.txt
# corpus\11048.txt
# corpus\11049.txt
# corpus\1105.txt
# corpus\11050.txt
# corpus\11051.txt
# corpus\11052.txt
# corpus\11053.txt
# corpus\11054.txt
# corpus\11055.txt
# corpus\11056.txt
# corpus\11057.txt
# corpus\11058.txt
# corpus\11059.txt
# corpus\1106.txt
# corpus\11060.txt
# corpus\11061.txt
# corpus\11062.txt
# corpus\11063.txt
# corpus\11064.txt
# corpus\11065.txt
# corpus\11066.txt
# corpus\11067.txt
# corpus\11068.txt
# corpus\11069.txt
# corpus\1107.txt
# corpus\11070.txt
# corpus\11071.txt
# corpus\11072.txt
# corpus\11073.txt
# corpus\11074.txt
# corpus\11075.txt
# corpus\11076.txt
# corpus\11077.txt
# corpus\11078.txt
# corpus\11079.txt
# corpus\1108.txt
# corpus\11080.txt
# corpus\11081.txt
# corpus\11082.txt
# corpus\11083.txt
# corpus\11084.txt
# corpus\11085.txt
# corpus\11086.txt
# corpus\11087.txt
# corpus\11088.txt
# corpus\11089.txt
# corpus\1109.txt
# corpus\11090.txt
# corpus\11091.txt
# corpus\11092.txt
# corpus\11093.txt
# corpus\11094.txt
# corpus\11095.txt
# corpus\11096.txt
# corpus\11097.txt
# corpus\11098.txt
# corpus\11099.txt
# corpus\111.txt
# corpus\1110.txt
# corpus\11100.txt
# corpus\11101.txt
# corpus\11102.txt
# corpus\11103.txt
# corpus\11104.txt
# corpus\11105.txt
# corpus\11106.txt
# corpus\11107.txt
# corpus\11108.txt
# corpus\11109.txt
# corpus\1111.txt
# corpus\11110.txt
# corpus\11111.txt
# corpus\11112.txt
# corpus\11113.txt
# corpus\11114.txt
# corpus\11115.txt
# corpus\11116.txt
# corpus\11117.txt
# corpus\11118.txt
# corpus\11119.txt
# corpus\1112.txt
# corpus\11120.txt
# corpus\11121.txt
# corpus\11122.txt
# corpus\11123.txt
# corpus\11124.txt
# corpus\11125.txt
# corpus\11126.txt
# corpus\11127.txt
# corpus\11128.txt
# corpus\11129.txt
# corpus\1113.txt
# corpus\11130.txt
# corpus\11131.txt
# corpus\11132.txt
# corpus\11133.txt
# corpus\11134.txt
# corpus\11135.txt
# corpus\11136.txt
# corpus\11137.txt
# corpus\11138.txt
# corpus\11139.txt
# corpus\1114.txt
# corpus\11140.txt
# corpus\11141.txt
# corpus\11514.txt
# corpus\11515.txt
# corpus\11516.txt
# corpus\11517.txt
# corpus\11518.txt
# corpus\11519.txt
# corpus\1152.txt
# corpus\11520.txt
# corpus\11521.txt
# corpus\11522.txt
# corpus\11523.txt
# corpus\11524.txt
# corpus\11525.txt
# corpus\11526.txt
# corpus\11527.txt
# corpus\11528.txt
# corpus\11529.txt
# corpus\1153.txt
# corpus\11530.txt
# corpus\11531.txt
# corpus\11532.txt
# corpus\11533.txt
# corpus\11534.txt
# corpus\11535.txt
# corpus\11536.txt
# corpus\11537.txt
# corpus\11538.txt
# corpus\11539.txt
# corpus\1154.txt
# corpus\11540.txt
# corpus\11541.txt
# corpus\11542.txt
# corpus\11543.txt
# corpus\11544.txt
# corpus\11545.txt
# corpus\11546.txt
# corpus\11547.txt
# corpus\11548.txt
# corpus\11549.txt
# corpus\1155.txt
# corpus\11550.txt
# corpus\11551.txt
# corpus\11552.txt
# corpus\11553.txt
# corpus\11554.txt
# corpus\11555.txt
# corpus\11556.txt
# corpus\11557.txt
# corpus\11558.txt
# corpus\11559.txt
# corpus\1156.txt
# corpus\11560.txt
# corpus\11561.txt
# corpus\11562.txt
# corpus\11563.txt
# corpus\11564.txt
# corpus\11565.txt
# corpus\11566.txt
# corpus\11567.txt
# corpus\11568.txt
# corpus\11569.txt
# corpus\1157.txt
# corpus\11570.txt
# corpus\11571.txt
# corpus\11572.txt
# corpus\11573.txt
# corpus\11574.txt
# corpus\11575.txt
# corpus\11576.txt
# corpus\11577.txt
# corpus\11578.txt
# corpus\11579.txt
# corpus\1158.txt
# corpus\11580.txt
# corpus\11581.txt
# corpus\11582.txt
# corpus\11583.txt
# corpus\11584.txt
# corpus\11585.txt
# corpus\11586.txt
# corpus\11587.txt
# corpus\11588.txt
# corpus\11589.txt
# corpus\1159.txt
# corpus\11590.txt
# corpus\11591.txt
# corpus\11592.txt
# corpus\11593.txt
# corpus\11594.txt
# corpus\11595.txt
# corpus\11596.txt
# corpus\11597.txt
# corpus\11598.txt
# corpus\11599.txt
# corpus\116.txt
# corpus\1160.txt
# corpus\11600.txt
# corpus\11601.txt
# corpus\11602.txt
# corpus\11603.txt
# corpus\11604.txt
# corpus\11605.txt
# corpus\11606.txt
# corpus\11607.txt
# corpus\11608.txt
# corpus\11609.txt
# corpus\1161.txt
# corpus\11610.txt
# corpus\11611.txt
# corpus\11612.txt
# corpus\11613.txt
# corpus\11614.txt
# corpus\11615.txt
# corpus\11616.txt
# corpus\11617.txt
# corpus\11618.txt
# corpus\11619.txt
# corpus\1162.txt
# corpus\11620.txt
# corpus\11621.txt
# corpus\11622.txt
# corpus\11623.txt
# corpus\11624.txt
# corpus\11625.txt
# corpus\11626.txt
# corpus\11627.txt
# corpus\11628.txt
# corpus\11629.txt
# corpus\1163.txt
# corpus\11630.txt
# corpus\11631.txt
# corpus\11632.txt
# corpus\11633.txt
# corpus\11634.txt
# corpus\11635.txt
# corpus\11636.txt
# corpus\11637.txt
# corpus\11638.txt
# corpus\11639.txt
# corpus\1164.txt
# corpus\11640.txt
# corpus\11641.txt
# corpus\11642.txt
# corpus\11643.txt
# corpus\11644.txt
# corpus\11645.txt
# corpus\11646.txt
# corpus\11647.txt
# corpus\11648.txt
# corpus\11649.txt
# corpus\1165.txt
# corpus\11650.txt
# corpus\11651.txt
# corpus\11652.txt
# corpus\11653.txt
# corpus\11654.txt
# corpus\11655.txt
# corpus\11656.txt
# corpus\11657.txt
# corpus\11658.txt
# corpus\11659.txt
# corpus\1166.txt
# corpus\11660.txt
# corpus\11661.txt
# corpus\11662.txt
# corpus\11663.txt
# corpus\11664.txt
# corpus\11665.txt
# corpus\11666.txt
# corpus\11667.txt
# corpus\11668.txt
# corpus\11669.txt
# corpus\1167.txt
# corpus\11670.txt
# corpus\11671.txt
# corpus\11672.txt
# corpus\11673.txt
# corpus\11674.txt
# corpus\11675.txt
# corpus\11676.txt
# corpus\11677.txt
# corpus\11678.txt
# corpus\11679.txt
# corpus\1168.txt
# corpus\11680.txt
# corpus\11681.txt
# corpus\11682.txt
# corpus\11683.txt
# corpus\11684.txt
# corpus\11685.txt
# corpus\11686.txt
# corpus\11687.txt
# corpus\11688.txt
# corpus\11689.txt
# corpus\1169.txt
# corpus\11690.txt
# corpus\11691.txt
# corpus\11692.txt
# corpus\11693.txt
# corpus\11694.txt
# corpus\11695.txt
# corpus\11696.txt
# corpus\11697.txt
# corpus\11698.txt
# corpus\11699.txt
# corpus\117.txt
# corpus\1170.txt
# corpus\11700.txt
# corpus\11701.txt
# corpus\11702.txt
# corpus\11703.txt
# corpus\11704.txt
# corpus\11705.txt
# corpus\11706.txt
# corpus\11707.txt
# corpus\11708.txt
# corpus\11709.txt
# corpus\1171.txt
# corpus\11710.txt
# corpus\11711.txt
# corpus\11712.txt
# corpus\11713.txt
# corpus\11714.txt
# corpus\11715.txt
# corpus\11716.txt
# corpus\11717.txt
# corpus\11718.txt
# corpus\11719.txt
# corpus\1172.txt
# corpus\11720.txt
# corpus\11721.txt
# corpus\11722.txt
# corpus\11723.txt
# corpus\11724.txt
# corpus\11725.txt
# corpus\11726.txt
# corpus\11727.txt
# corpus\11728.txt
# corpus\11729.txt
# corpus\1173.txt
# corpus\11730.txt
# corpus\11731.txt
# corpus\11732.txt
# corpus\11733.txt
# corpus\11734.txt
# corpus\11735.txt
# corpus\11736.txt
# corpus\11737.txt
# corpus\11738.txt
# corpus\11739.txt
# corpus\1174.txt
# corpus\11740.txt
# corpus\11741.txt
# corpus\11742.txt
# corpus\11743.txt
# corpus\11744.txt
# corpus\11745.txt
# corpus\11746.txt
# corpus\11747.txt
# corpus\11748.txt
# corpus\11749.txt
# corpus\1175.txt
# corpus\11750.txt
# corpus\11751.txt
# corpus\11752.txt
# corpus\11753.txt
# corpus\11754.txt
# corpus\11755.txt
# corpus\11756.txt
# corpus\11757.txt
# corpus\11758.txt
# corpus\11759.txt
# corpus\1176.txt
# corpus\11760.txt
# corpus\11761.txt
# corpus\11762.txt
# corpus\11763.txt
# corpus\11764.txt
# corpus\11765.txt
# corpus\11766.txt
# corpus\11767.txt
# corpus\11768.txt
# corpus\11769.txt
# corpus\1177.txt
# corpus\11770.txt
# corpus\11771.txt
# corpus\11772.txt
# corpus\11773.txt
# corpus\11774.txt
# corpus\11775.txt
# corpus\11776.txt
# corpus\11777.txt
# corpus\11778.txt
# corpus\11779.txt
# corpus\1178.txt
# corpus\11780.txt
# corpus\11781.txt
# corpus\11782.txt
# corpus\11783.txt
# corpus\11784.txt
# corpus\11785.txt
# corpus\11786.txt
# corpus\11787.txt
# corpus\11788.txt
# corpus\11789.txt
# corpus\1179.txt
# corpus\11790.txt
# corpus\11791.txt
# corpus\11792.txt
# corpus\11793.txt
# corpus\11794.txt
# corpus\11795.txt
# corpus\11796.txt
# corpus\11797.txt
# corpus\11798.txt
# corpus\11799.txt
# corpus\118.txt
# corpus\1180.txt
# corpus\11800.txt
# corpus\11801.txt
# corpus\11802.txt
# corpus\11803.txt
# corpus\11804.txt
# corpus\11805.txt
# corpus\11806.txt
# corpus\11807.txt
# corpus\11808.txt
# corpus\11809.txt
# corpus\1181.txt
# corpus\11810.txt
# corpus\11811.txt
# corpus\11812.txt
# corpus\11813.txt
# corpus\11814.txt
# corpus\11815.txt
# corpus\11816.txt
# corpus\11817.txt
# corpus\11818.txt
# corpus\11819.txt
# corpus\1182.txt
# corpus\11820.txt
# corpus\11821.txt
# corpus\11822.txt
# corpus\11823.txt
# corpus\11824.txt
# corpus\11825.txt
# corpus\11826.txt
# corpus\11827.txt
# corpus\11828.txt
# corpus\11829.txt
# corpus\1183.txt
# corpus\11830.txt
# corpus\11831.txt
# corpus\11832.txt
# corpus\11833.txt
# corpus\11834.txt
# corpus\11835.txt
# corpus\11836.txt
# corpus\11837.txt
# corpus\11838.txt
# corpus\11839.txt
# corpus\1184.txt
# corpus\11840.txt
# corpus\11841.txt
# corpus\11842.txt
# corpus\11843.txt
# corpus\11844.txt
# corpus\11845.txt
# corpus\11846.txt
# corpus\11847.txt
# corpus\11848.txt
# corpus\11849.txt
# corpus\1185.txt
# corpus\11850.txt
# corpus\11851.txt
# corpus\11852.txt
# corpus\11853.txt
# corpus\11854.txt
# corpus\11855.txt
# corpus\11856.txt
# corpus\11857.txt
# corpus\11858.txt
# corpus\11859.txt
# corpus\1186.txt
# corpus\11860.txt
# corpus\11861.txt
# corpus\11862.txt
# corpus\11863.txt
# corpus\11864.txt
# corpus\11865.txt
# corpus\11866.txt
# corpus\11867.txt
# corpus\11868.txt
# corpus\11869.txt
# corpus\1187.txt
# corpus\11870.txt
# corpus\11871.txt
# corpus\11872.txt
# corpus\11873.txt
# corpus\11874.txt
# corpus\11875.txt
# corpus\11876.txt
# corpus\11877.txt
# corpus\11878.txt
# corpus\11879.txt
# corpus\1188.txt
# corpus\11880.txt
# corpus\11881.txt
# corpus\11882.txt
# corpus\11883.txt
# corpus\11884.txt
# corpus\11885.txt
# corpus\11886.txt
# corpus\11887.txt
# corpus\11888.txt
# corpus\11889.txt
# corpus\1189.txt
# corpus\11890.txt
# corpus\11891.txt
# corpus\11892.txt
# corpus\11893.txt
# corpus\11894.txt
# corpus\11895.txt
# corpus\11896.txt
# corpus\11897.txt
# corpus\11898.txt
# corpus\11899.txt
# corpus\119.txt
# corpus\1190.txt
# corpus\11900.txt
# corpus\11901.txt
# corpus\11902.txt
# corpus\11903.txt
# corpus\11904.txt
# corpus\11905.txt
# corpus\11906.txt
# corpus\11907.txt
# corpus\11908.txt
# corpus\11909.txt
# corpus\1191.txt
# corpus\11910.txt
# corpus\11911.txt
# corpus\11912.txt
# corpus\11913.txt
# corpus\11914.txt
# corpus\11915.txt
# corpus\11916.txt
# corpus\11917.txt
# corpus\11918.txt
# corpus\11919.txt
# corpus\1192.txt
# corpus\11920.txt
# corpus\11921.txt
# corpus\11922.txt
# corpus\11923.txt
# corpus\11924.txt
# corpus\11925.txt
# corpus\11926.txt
# corpus\11927.txt
# corpus\11928.txt
# corpus\11929.txt
# corpus\1193.txt
# corpus\11930.txt
# corpus\11931.txt
# corpus\11932.txt
# corpus\11933.txt
# corpus\11934.txt
# corpus\11935.txt
# corpus\11936.txt
# corpus\11937.txt
# corpus\11938.txt
# corpus\11939.txt
# corpus\1194.txt
# corpus\11940.txt
# corpus\11941.txt
# corpus\11942.txt
# corpus\11943.txt
# corpus\11944.txt
# corpus\11945.txt
# corpus\11946.txt
# corpus\11947.txt
# corpus\11948.txt
# corpus\11949.txt
# corpus\1195.txt
# corpus\11950.txt
# corpus\11951.txt
# corpus\11952.txt
# corpus\11953.txt
# corpus\11954.txt
# corpus\11955.txt
# corpus\11956.txt
# corpus\11957.txt
# corpus\11958.txt
# corpus\11959.txt
# corpus\1196.txt
# corpus\11960.txt
# corpus\11961.txt
# corpus\11962.txt
# corpus\11963.txt
# corpus\11964.txt
# corpus\11965.txt
# corpus\11966.txt
# corpus\11967.txt
# corpus\11968.txt
# corpus\11969.txt
# corpus\1197.txt
# corpus\11970.txt
# corpus\11971.txt
# corpus\11972.txt
# corpus\11973.txt
# corpus\11974.txt
# corpus\11975.txt
# corpus\11976.txt
# corpus\11977.txt
# corpus\11978.txt
# corpus\11979.txt
# corpus\1198.txt
# corpus\11980.txt
# corpus\11981.txt
# corpus\11982.txt
# corpus\11983.txt
# corpus\11984.txt
# corpus\11985.txt
# corpus\11986.txt
# corpus\11987.txt
# corpus\11988.txt
# corpus\11989.txt
# corpus\1199.txt
# corpus\11990.txt
# corpus\11991.txt
# corpus\11992.txt
# corpus\11993.txt
# corpus\11994.txt
# corpus\11995.txt
# corpus\11996.txt
# corpus\11997.txt
# corpus\11998.txt
# corpus\11999.txt
# corpus\12.txt
# corpus\120.txt
# corpus\1200.txt
# corpus\12000.txt
# corpus\12001.txt
# corpus\12002.txt
# corpus\12003.txt
# corpus\12004.txt
# corpus\12005.txt
# corpus\12006.txt
# corpus\12007.txt
# corpus\12008.txt
# corpus\12009.txt
# corpus\1201.txt
# corpus\12010.txt
# corpus\12011.txt
# corpus\12012.txt
# corpus\12013.txt
# corpus\12014.txt
# corpus\12015.txt
# corpus\12016.txt
# corpus\12017.txt
# corpus\12018.txt
# corpus\12019.txt
# corpus\1202.txt
# corpus\12020.txt
# corpus\12021.txt
# corpus\12022.txt
# corpus\12023.txt
# corpus\12024.txt
# corpus\12025.txt
# corpus\12026.txt
# corpus\12027.txt
# corpus\12028.txt
# corpus\12029.txt
# corpus\1203.txt
# corpus\12030.txt
# corpus\12031.txt
# corpus\12032.txt
# corpus\12033.txt
# corpus\12034.txt
# corpus\12035.txt
# corpus\12036.txt
# corpus\12037.txt
# corpus\12038.txt
# corpus\12039.txt
# corpus\1204.txt
# corpus\12040.txt
# corpus\12041.txt
# corpus\12042.txt
# corpus\12043.txt
# corpus\12044.txt
# corpus\12045.txt
# corpus\12046.txt
# corpus\12047.txt
# corpus\12048.txt
# corpus\12049.txt
# corpus\1205.txt
# corpus\12050.txt
# corpus\12051.txt
# corpus\12052.txt
# corpus\12053.txt
# corpus\12054.txt
# corpus\12055.txt
# corpus\12056.txt
# corpus\12057.txt
# corpus\12058.txt
# corpus\12059.txt
# corpus\1206.txt
# corpus\12060.txt
# corpus\12061.txt
# corpus\12062.txt
# corpus\12063.txt
# corpus\12064.txt
# corpus\12065.txt
# corpus\12066.txt
# corpus\12067.txt
# corpus\12068.txt
# corpus\12069.txt
# corpus\1207.txt
# corpus\12070.txt
# corpus\12071.txt
# corpus\12072.txt
# corpus\12073.txt
# corpus\12074.txt
# corpus\12075.txt
# corpus\12076.txt
# corpus\12077.txt
# corpus\12078.txt
# corpus\12079.txt
# corpus\1208.txt
# corpus\12080.txt
# corpus\12081.txt
# corpus\12082.txt
# corpus\12083.txt
# corpus\12084.txt
# corpus\12085.txt
# corpus\12086.txt
# corpus\12087.txt
# corpus\12088.txt
# corpus\12089.txt
# corpus\1209.txt
# corpus\12090.txt
# corpus\12091.txt
# corpus\12092.txt
# corpus\12093.txt
# corpus\12094.txt
# corpus\12095.txt
# corpus\12096.txt
# corpus\12097.txt
# corpus\12098.txt
# corpus\12099.txt
# corpus\121.txt
# corpus\1210.txt
# corpus\12100.txt
# corpus\12101.txt
# corpus\12102.txt
# corpus\12103.txt
# corpus\12104.txt
# corpus\12105.txt
# corpus\12106.txt
# corpus\12107.txt
# corpus\12108.txt
# corpus\12109.txt
# corpus\1211.txt
# corpus\12110.txt
# corpus\12111.txt
# corpus\12112.txt
# corpus\12113.txt
# corpus\12114.txt
# corpus\12115.txt
# corpus\12116.txt
# corpus\12117.txt
# corpus\12118.txt
# corpus\12119.txt
# corpus\1212.txt
# corpus\12120.txt
# corpus\12121.txt
# corpus\12122.txt
# corpus\12123.txt
# corpus\12124.txt
# corpus\12125.txt
# corpus\12126.txt
# corpus\12127.txt
# corpus\12128.txt
# corpus\12129.txt
# corpus\1213.txt
# corpus\12130.txt
# corpus\12131.txt
# corpus\12132.txt
# corpus\12133.txt
# corpus\12134.txt
# corpus\12135.txt
# corpus\12136.txt
# corpus\12137.txt
# corpus\12138.txt
# corpus\12139.txt
# corpus\1214.txt
# corpus\12140.txt
# corpus\12141.txt
# corpus\12142.txt
# corpus\12143.txt
# corpus\12144.txt
# corpus\12145.txt
# corpus\12146.txt
# corpus\12147.txt
# corpus\12148.txt
# corpus\12149.txt
# corpus\1215.txt
# corpus\12150.txt
# corpus\12151.txt
# corpus\12152.txt
# corpus\12153.txt
# corpus\12154.txt
# corpus\12155.txt
# corpus\12156.txt
# corpus\12157.txt
# corpus\12158.txt
# corpus\12159.txt
# corpus\1216.txt
# corpus\12160.txt
# corpus\12161.txt
# corpus\12162.txt
# corpus\12163.txt
# corpus\12164.txt
# corpus\12165.txt
# corpus\12166.txt
# corpus\12167.txt
# corpus\12168.txt
# corpus\12169.txt
# corpus\1217.txt
# corpus\12170.txt
# corpus\12171.txt
# corpus\12172.txt
# corpus\12173.txt
# corpus\12174.txt
# corpus\12175.txt
# corpus\12176.txt
# corpus\12177.txt
# corpus\12178.txt
# corpus\12179.txt
# corpus\1218.txt
# corpus\12180.txt
# corpus\12181.txt
# corpus\12182.txt
# corpus\12183.txt
# corpus\12184.txt
# corpus\12185.txt
# corpus\12186.txt
# corpus\12187.txt
# corpus\12188.txt
# corpus\12189.txt
# corpus\1219.txt
# corpus\12190.txt
# corpus\12191.txt
# corpus\12192.txt
# corpus\12193.txt
# corpus\12194.txt
# corpus\12195.txt
# corpus\12196.txt
# corpus\12197.txt
# corpus\12198.txt
# corpus\12199.txt
# corpus\122.txt
# corpus\1220.txt
# corpus\12200.txt
# corpus\12201.txt
# corpus\12202.txt
# corpus\12203.txt
# corpus\12204.txt
# corpus\12205.txt
# corpus\12206.txt
# corpus\12207.txt
# corpus\12208.txt
# corpus\12209.txt
# corpus\1221.txt
# corpus\12210.txt
# corpus\12211.txt
# corpus\12212.txt
# corpus\12213.txt
# corpus\12214.txt
# corpus\12215.txt
# corpus\12216.txt
# corpus\12217.txt
# corpus\12218.txt
# corpus\12219.txt
# corpus\1222.txt
# corpus\12220.txt
# corpus\12221.txt
# corpus\12222.txt
# corpus\12223.txt
# corpus\12224.txt
# corpus\12225.txt
# corpus\12226.txt
# corpus\12227.txt
# corpus\12228.txt
# corpus\12229.txt
# corpus\1223.txt
# corpus\12230.txt
# corpus\12231.txt
# corpus\12232.txt
# corpus\12233.txt
# corpus\12234.txt
# corpus\12235.txt
# corpus\12236.txt
# corpus\12237.txt
# corpus\12238.txt
# corpus\12239.txt
# corpus\1224.txt
# corpus\12240.txt
# corpus\12241.txt
# corpus\12242.txt
# corpus\12243.txt
# corpus\12244.txt
# corpus\12245.txt
# corpus\12246.txt
# corpus\12247.txt
# corpus\12248.txt
# corpus\12249.txt
# corpus\1225.txt
# corpus\12250.txt
# corpus\12251.txt
# corpus\12252.txt
# corpus\12253.txt
# corpus\12254.txt
# corpus\12255.txt
# corpus\12256.txt
# corpus\12257.txt
# corpus\12258.txt
# corpus\12259.txt
# corpus\1226.txt
# corpus\12260.txt
# corpus\12261.txt
# corpus\12262.txt
# corpus\12263.txt
# corpus\12264.txt
# corpus\12265.txt
# corpus\12266.txt
# corpus\12267.txt
# corpus\12268.txt
# corpus\12269.txt
# corpus\1227.txt
# corpus\12270.txt
# corpus\12271.txt
# corpus\12272.txt
# corpus\12273.txt
# corpus\12274.txt
# corpus\12275.txt
# corpus\12276.txt
# corpus\12277.txt
# corpus\12278.txt
# corpus\12279.txt
# corpus\1228.txt
# corpus\12280.txt
# corpus\12281.txt
# corpus\12282.txt
# corpus\12283.txt
# corpus\12284.txt
# corpus\12285.txt
# corpus\12286.txt
# corpus\12287.txt
# corpus\12288.txt
# corpus\12289.txt
# corpus\1229.txt
# corpus\12290.txt
# corpus\12291.txt
# corpus\12292.txt
# corpus\12293.txt
# corpus\12294.txt
# corpus\12295.txt
# corpus\12296.txt
# corpus\12297.txt
# corpus\12298.txt
# corpus\12299.txt
# corpus\123.txt
# corpus\1230.txt
# corpus\12300.txt
# corpus\12301.txt
# corpus\12302.txt
# corpus\12303.txt
# corpus\12304.txt
# corpus\12305.txt
# corpus\12306.txt
# corpus\12307.txt
# corpus\12308.txt
# corpus\12309.txt
# corpus\1231.txt
# corpus\12310.txt
# corpus\12311.txt
# corpus\12312.txt
# corpus\12313.txt
# corpus\12314.txt
# corpus\12315.txt
# corpus\12316.txt
# corpus\12317.txt
# corpus\12318.txt
# corpus\12319.txt
# corpus\1232.txt
# corpus\12320.txt
# corpus\12321.txt
# corpus\12322.txt
# corpus\12323.txt
# corpus\12324.txt
# corpus\12325.txt
# corpus\12326.txt
# corpus\12327.txt
# corpus\12328.txt
# corpus\12329.txt
# corpus\1233.txt
# corpus\12330.txt
# corpus\12331.txt
# corpus\12332.txt
# corpus\12333.txt
# corpus\12334.txt
# corpus\12335.txt
# corpus\12336.txt
# corpus\12337.txt
# corpus\12338.txt
# corpus\12339.txt
# corpus\1234.txt
# corpus\12340.txt
# corpus\12341.txt
# corpus\12342.txt
# corpus\12343.txt
# corpus\12344.txt
# corpus\12345.txt
# corpus\12346.txt
# corpus\12347.txt
# corpus\12348.txt
# corpus\12349.txt
# corpus\1235.txt
# corpus\12350.txt
# corpus\12351.txt
# corpus\12352.txt
# corpus\12353.txt
# corpus\12354.txt
# corpus\12355.txt
# corpus\12356.txt
# corpus\12357.txt
# corpus\12358.txt
# corpus\12359.txt
# corpus\1236.txt
# corpus\12360.txt
# corpus\12361.txt
# corpus\12362.txt
# corpus\12363.txt
# corpus\12364.txt
# corpus\12365.txt
# corpus\12366.txt
# corpus\12367.txt
# corpus\12368.txt
# corpus\12369.txt
# corpus\1237.txt
# corpus\12370.txt
# corpus\12371.txt
# corpus\12372.txt
# corpus\12373.txt
# corpus\12374.txt
# corpus\12375.txt
# corpus\12376.txt
# corpus\12377.txt
# corpus\12378.txt
# corpus\12379.txt
# corpus\1238.txt
# corpus\12380.txt
# corpus\12381.txt
# corpus\12382.txt
# corpus\12383.txt
# corpus\12384.txt
# corpus\12385.txt
# corpus\12386.txt
# corpus\12387.txt
# corpus\12388.txt
# corpus\12389.txt
# corpus\1239.txt
# corpus\12390.txt
# corpus\12391.txt
# corpus\12392.txt
# corpus\12393.txt
# corpus\12394.txt
# corpus\12395.txt
# corpus\12396.txt
# corpus\12397.txt
# corpus\12398.txt
# corpus\12399.txt
# corpus\124.txt
# corpus\1240.txt
# corpus\12400.txt
# corpus\12401.txt
# corpus\12402.txt
# corpus\12403.txt
# corpus\12404.txt
# corpus\12405.txt
# corpus\12406.txt
# corpus\12407.txt
# corpus\12408.txt
# corpus\12409.txt
# corpus\1241.txt
# corpus\12410.txt
# corpus\12411.txt
# corpus\12412.txt
# corpus\12413.txt
# corpus\12414.txt
# corpus\12415.txt
# corpus\12416.txt
# corpus\12417.txt
# corpus\12418.txt
# corpus\12419.txt
# corpus\1242.txt
# corpus\12420.txt
# corpus\12421.txt
# corpus\12422.txt
# corpus\12423.txt
# corpus\12424.txt
# corpus\12425.txt
# corpus\12426.txt
# corpus\12427.txt
# corpus\12428.txt
# corpus\12429.txt
# corpus\1243.txt
# corpus\12430.txt
# corpus\12431.txt
# corpus\12432.txt
# corpus\12433.txt
# corpus\12434.txt
# corpus\12435.txt
# corpus\12436.txt
# corpus\12437.txt
# corpus\12438.txt
# corpus\12439.txt
# corpus\1244.txt
# corpus\12440.txt
# corpus\12441.txt
# corpus\12442.txt
# corpus\12443.txt
# corpus\12444.txt
# corpus\12445.txt
# corpus\12446.txt
# corpus\12447.txt
# corpus\12448.txt
# corpus\12449.txt
# corpus\1245.txt
# corpus\12450.txt
# corpus\12451.txt
# corpus\12452.txt
# corpus\12453.txt
# corpus\12454.txt
# corpus\12455.txt
# corpus\12456.txt
# corpus\12457.txt
# corpus\12458.txt
# corpus\12459.txt
# corpus\1246.txt
# corpus\12460.txt
# corpus\12461.txt
# corpus\12462.txt
# corpus\12463.txt
# corpus\12464.txt
# corpus\12465.txt
# corpus\12466.txt
# corpus\12467.txt
# corpus\12468.txt
# corpus\12469.txt
# corpus\1247.txt
# corpus\12470.txt
# corpus\12471.txt
# corpus\12472.txt
# corpus\12473.txt
# corpus\12474.txt
# corpus\12475.txt
# corpus\12476.txt
# corpus\12477.txt
# corpus\12478.txt
# corpus\12479.txt
# corpus\1248.txt
# corpus\12480.txt
# corpus\12481.txt
# corpus\12482.txt
# corpus\12483.txt
# corpus\12484.txt
# corpus\12485.txt
# corpus\12486.txt
# corpus\12487.txt
# corpus\12488.txt
# corpus\12489.txt
# corpus\1249.txt
# corpus\12490.txt
# corpus\12491.txt
# corpus\12492.txt
# corpus\12493.txt
# corpus\12494.txt
# corpus\12495.txt
# corpus\12496.txt
# corpus\12497.txt
# corpus\12498.txt
# corpus\12499.txt
# corpus\125.txt
# corpus\1250.txt
# corpus\12500.txt
# corpus\12501.txt
# corpus\12502.txt
# corpus\12503.txt
# corpus\12504.txt
# corpus\12505.txt
# corpus\12506.txt
# corpus\12507.txt
# corpus\12508.txt
# corpus\12509.txt
# corpus\1251.txt
# corpus\12510.txt
# corpus\12511.txt
# corpus\12512.txt
# corpus\12513.txt
# corpus\12514.txt
# corpus\12515.txt
# corpus\12516.txt
# corpus\12517.txt
# corpus\12518.txt
# corpus\12519.txt
# corpus\1252.txt
# corpus\12520.txt
# corpus\12521.txt
# corpus\12522.txt
# corpus\12523.txt
# corpus\12524.txt
# corpus\12525.txt
# corpus\12526.txt
# corpus\12527.txt
# corpus\12528.txt
# corpus\12529.txt
# corpus\1253.txt
# corpus\12530.txt
# corpus\12531.txt
# corpus\12532.txt
# corpus\12533.txt
# corpus\12534.txt
# corpus\12535.txt
# corpus\12536.txt
# corpus\12537.txt
# corpus\12538.txt
# corpus\12539.txt
# corpus\1254.txt
# corpus\12540.txt
# corpus\12541.txt
# corpus\12542.txt
# corpus\12543.txt
# corpus\12544.txt
# corpus\12545.txt
# corpus\12546.txt
# corpus\12547.txt
# corpus\12548.txt
# corpus\12549.txt
# corpus\1255.txt
# corpus\12550.txt
# corpus\12551.txt
# corpus\12552.txt
# corpus\12553.txt
# corpus\12554.txt
# ...
# corpus\9093.txt
# corpus\9094.txt
# corpus\9095.txt
# corpus\9096.txt
# corpus\9097.txt
# corpus\9098.txt
# corpus\9099.txt
# corpus\91.txt
# corpus\910.txt
# corpus\9100.txt
# corpus\9101.txt
# corpus\9102.txt
# corpus\9103.txt
# corpus\9104.txt
# corpus\9105.txt
# corpus\9106.txt
# corpus\9107.txt
# corpus\9108.txt
# corpus\9109.txt
# corpus\911.txt
# corpus\9110.txt
# corpus\9111.txt
# corpus\9112.txt
# corpus\9113.txt
# corpus\9114.txt
# corpus\9115.txt
# corpus\9116.txt
# corpus\9117.txt
# corpus\9118.txt
# corpus\9119.txt
# corpus\912.txt
# corpus\9120.txt
# corpus\9121.txt
# corpus\9122.txt
# corpus\9123.txt
# corpus\9124.txt
# corpus\9125.txt
# corpus\9126.txt
# corpus\9127.txt
# corpus\9128.txt
# corpus\9129.txt
# corpus\913.txt
# corpus\9130.txt
# corpus\9131.txt
# corpus\9132.txt
# corpus\9133.txt
# corpus\9134.txt
# corpus\9135.txt
# corpus\9136.txt
# corpus\9137.txt
# corpus\9138.txt
# corpus\9139.txt
# corpus\914.txt
# corpus\9140.txt
# corpus\9141.txt
# corpus\9142.txt
# corpus\9143.txt
# corpus\9144.txt
# corpus\9145.txt
# corpus\9146.txt
# corpus\9147.txt
# corpus\9148.txt
# corpus\9149.txt
# corpus\915.txt
# corpus\9150.txt
# corpus\9151.txt
# corpus\9152.txt
# corpus\9153.txt
# corpus\9154.txt
# corpus\9155.txt
# corpus\9156.txt
# corpus\9157.txt
# corpus\9158.txt
# corpus\9159.txt
# corpus\916.txt
# corpus\9160.txt
# corpus\9161.txt
# corpus\9162.txt
# corpus\9163.txt
# corpus\9164.txt
# corpus\9165.txt
# corpus\9166.txt
# corpus\9167.txt
# corpus\9917.txt
# corpus\9918.txt
# corpus\9919.txt
# corpus\992.txt
# corpus\9920.txt
# corpus\9921.txt
# corpus\9922.txt
# corpus\9923.txt
# corpus\9924.txt
# corpus\9925.txt
# corpus\9926.txt
# corpus\9927.txt
# corpus\9928.txt
# corpus\9929.txt
# corpus\993.txt
# corpus\9930.txt
# corpus\9931.txt
# corpus\9932.txt
# corpus\9933.txt
# corpus\9934.txt
# corpus\9935.txt
# corpus\9936.txt
# corpus\9937.txt
# corpus\9938.txt
# corpus\9939.txt
# corpus\994.txt
# corpus\9940.txt
# corpus\9941.txt
# corpus\9942.txt
# corpus\9943.txt
# corpus\9944.txt
# corpus\9945.txt
# corpus\9946.txt
# corpus\9947.txt
# corpus\9948.txt
# corpus\9949.txt
# corpus\995.txt
# corpus\9950.txt
# corpus\9951.txt
# corpus\9952.txt
# corpus\9953.txt
# corpus\9954.txt
# corpus\9955.txt
# corpus\9956.txt
# corpus\9957.txt
# corpus\9958.txt
# corpus\9959.txt
# corpus\996.txt
# corpus\9960.txt
# corpus\9961.txt
# corpus\9962.txt
# corpus\9963.txt
# corpus\9964.txt
# corpus\9965.txt
# corpus\9966.txt
# corpus\9967.txt
# corpus\9968.txt
# corpus\9969.txt
# corpus\997.txt
# corpus\9970.txt
# corpus\9971.txt
# corpus\9972.txt
# corpus\9973.txt
# corpus\9974.txt
# corpus\9975.txt
# corpus\9976.txt
# corpus\9977.txt
# corpus\9978.txt
# corpus\9979.txt
# corpus\998.txt
# corpus\9980.txt
# corpus\9981.txt
# corpus\9982.txt
# corpus\9983.txt
# corpus\9984.txt
# corpus\9985.txt
# corpus\9986.txt
# corpus\9987.txt
# corpus\9988.txt
# corpus\9989.txt
# corpus\999.txt
# corpus\9990.txt
# corpus\9991.txt
# corpus\9992.txt
# corpus\9993.txt
# corpus\9994.txt
# corpus\9995.txt
# corpus\9996.txt
# corpus\9997.txt
# corpus\9998.txt
# corpus\9999.txt

# %% [markdown]
# ## 2. Querying Indexed Data : Whoosh
#
# Querying a indexed data has two important parts which you may like to look upon.
#
# <u><b>Query String</b></u> : It is passed while searching the indexed data. Query string can be a single word, a single sentence to be matched exactly, multiple words with ‘AND’, multiple words with ‘OR’ etc. For examples –
#
# Query : politics (returns if the word occurs)Query : sports OR games OR play (returns if any one of the strings occur)
# Query : alpha beta gamma (return if a document contains all strings)
# Query : “alpha beta gamma“ (returns if all strings occur together in a document).
#
# <u><b>Scoring</b></u> : Each document is ranked according to a scoring function. There are quite a few types of scoring function supported by whoosh.
#
# <ol>
#     <li>
#         Frequency : It simply returns the count of the terms occurred in the document. It does not perform any normalization or weighting.
#     </li><li>
#     Tf-Idf scores : It returns tf * idf scores of each document. To know more read here or wiki page here.
#     </li><li>
#     BM25F scoring : It is the by default ranking function used by whoosh. BM stands for best matching. It is based on tf-idf along with bunch of factors like length of document in words, average length of documents in the collection. It also has free parameters k = 1.2 and b = 0.75. To read more check <a href="https://en.wikipedia.org/wiki/Okapi_BM25">here</a>.
#     </li><li>
#     Cosine scoring : It is useful for finding document similar to your search query.
#     </li>
# </ol>
# There are few more scoring algorithms which has been implemented. Check [here](https://github.com/jerem/Whoosh/blob/master/src/whoosh/scoring.py) to know more.
#
# Below is the python implementation for searching a query in the indexed database.

# %%
from whoosh.qparser import QueryParser
from whoosh import scoring
from whoosh.index import open_dir
 
ix = open_dir("indexdir")
 
# query_str is query string
# query_str = sys.argv[1]
query_str = "hello world"
# Top 'n' documents as result
# topN = int(sys.argv[2])
topN = 10
 
with ix.searcher(weighting=scoring.Frequency) as searcher:
    query = QueryParser("content", ix.schema).parse(query_str)
    results = searcher.search(query,limit=topN)
    res_len = len(results)
    real_top = min(topN,res_len)
    print('Топ {:d}/{:d}:\n'.format(real_top,res_len))
    for i in range(real_top):
        # print(results[i]['title'], str(results[i].score), results[i]['textdata'])
        print('{:>9} {:4.1f}'.format(results[i]['title'], results[i].score))
# Out:
# Топ 5/5:
#
# 22338.txt  3.0
# 67326.txt  3.0
# 52231.txt  2.0
# 63726.txt  2.0
#  8544.txt  2.0

# %% [markdown]
# QueryParser class of whoosh implements query language very similar to java Lucene’s.
#
# ## 3. Glossary
#
# Below are the basic terminologies you will always come across in discussions involving searching and indexing documents (taken from whoosh [docs](https://whoosh.readthedocs.io/en/latest/glossary.html)).
#
# **Corpus**
#
# The set of documents you are indexing.
#
# **Documents**
#
# The individual pieces of content you want to make searchable. The word “documents” might imply files, but the data source could really be anything – articles in a content management system, blog posts in a blogging system, chunks of a very large file, rows returned from an SQL query, individual email messages from a mailbox file, or whatever. When you get search results from Whoosh, the results are a list of documents, whatever “documents” means in your search engine.
#
# **Fields**
#
# Each document contains a set of fields. Typical fields might be “title”, “content”, “url”, “keywords”, “status”, “date”, etc. Fields can be indexed (so they’re searchable) and/or stored with the document. Storing the field makes it available in search results. For example, you typically want to store the “title” field so your search results can display it.
#
# **Forward index**
#
# A table listing every document and the words that appear in the document. Whoosh lets you store term vectors that are a kind of forward index.
#
# **Indexing**
#
# The process of examining documents in the corpus and adding them to the reverse index.
#
# **Postings**
#
# The reverse index lists every word in the corpus, and for each word, a list of documents in which that word appears, along with some optional information (such as the number of times the word appears in that document). These items in the list, containing a document number and any extra information, are called postings. In Whoosh the information stored in postings is customizable for each field.
#
# **Reverse Index**
#
# Basically a table listing every word in the corpus, and for each word, the list of documents in which it appears. It can be more complicated (the index can also list how many times the word appears in each document, the positions at which it appears, etc.) but that’s how it basically works.
#
# **Schema**
#
# Whoosh requires that you specify the fields of the index before you begin indexing. The Schema associates field names with metadata about the field, such as the format of the postings and whether the contents of the field are stored in the index.
#
# **Term vector**
#
# A forward index for a certain field in a certain document. You can specify in the Schema that a given field should store term vectors.
#
# ## At the End
#
# Hope it was an easy read and good heads-up to start with. So, what can we do more from here:
#
# 1. Searching for alike documents instead of exact term searches only.
# 2. Exploring hierarchical search in file system.
# 3. Correcting errors in the queries. Did you mean…?
# 4. Search N-grams for getting fast, “search as you type” functionality
